# %% [markdown]
# ## 1. Multi-class and Multi-Label Classification Using Support Vector Machines

# %% [markdown]
# ### (a) Download the Anuran Calls (MFCCs) Data Set from: https://archive.ics.uci.edu/ml/datasets/Anuran+Calls+%28MFCCs%29. Choose 70% of the data randomly as the training set.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re,random
from sklearn import svm
import warnings
warnings.filterwarnings("ignore")
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report,hamming_loss
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
path='../data/Frogs_MFCCs.csv'
df = pd.read_csv(path,sep=',',skiprows=0)
df
# Out:
#       MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0          1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1          1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2          1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3          1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4          1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
# ...        ...       ...       ...       ...       ...       ...       ...
# 7190       1.0 -0.554504 -0.337717  0.035533  0.034511  0.443451  0.093889
# 7191       1.0 -0.517273 -0.370574  0.030673  0.068097  0.402890  0.096628
# 7192       1.0 -0.582557 -0.343237  0.029468  0.064179  0.385596  0.114905
# 7193       1.0 -0.519497 -0.307553 -0.004922  0.072865  0.377131  0.086866
# 7194       1.0 -0.508833 -0.324106  0.062068  0.078211  0.397188  0.094596
#
#       MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  \
# 0    -0.150063 -0.171128  0.124676  ... -0.108351 -0.077623 -0.009568
# 1    -0.222475 -0.207693  0.170883  ... -0.090974 -0.056510 -0.035303
# 2    -0.242234 -0.219153  0.232538  ... -0.050691 -0.023590 -0.066722
# 3    -0.194347 -0.098181  0.270375  ... -0.136009 -0.177037 -0.130498
# 4    -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550
# ...        ...       ...       ...  ...       ...       ...       ...
# 7190 -0.100753  0.037087  0.081075  ...  0.069430  0.071001  0.021591
# 7191 -0.116460  0.063727  0.089034  ...  0.061127  0.068978  0.017745
# 7192 -0.103317  0.070370  0.081317  ...  0.082474  0.077771 -0.009688
# 7193 -0.115799  0.056979  0.089316  ...  0.051796  0.069073  0.017963
# 7194 -0.117672  0.058874  0.076180  ...  0.061455  0.072983 -0.003980
#
#       MFCCs_20  MFCCs_21  MFCCs_22           Family      Genus  \
# 0     0.057684  0.118680  0.014038  Leptodactylidae  Adenomera
# 1     0.020140  0.082263  0.029056  Leptodactylidae  Adenomera
# 2    -0.025083  0.099108  0.077162  Leptodactylidae  Adenomera
# 3    -0.054766 -0.018691  0.023954  Leptodactylidae  Adenomera
# 4    -0.031346  0.108610  0.079244  Leptodactylidae  Adenomera
# ...        ...       ...       ...              ...        ...
# 7190  0.052449 -0.021860 -0.079860          Hylidae     Scinax
# 7191  0.046461 -0.015418 -0.101892          Hylidae     Scinax
# 7192  0.027834 -0.000531 -0.080425          Hylidae     Scinax
# 7193  0.041803 -0.027911 -0.096895          Hylidae     Scinax
# 7194  0.031560 -0.029355 -0.087910          Hylidae     Scinax
#
#              Species  RecordID
# 0     AdenomeraAndre         1
# 1     AdenomeraAndre         1
# 2     AdenomeraAndre         1
# 3     AdenomeraAndre         1
# 4     AdenomeraAndre         1
# ...              ...       ...
# 7190     ScinaxRuber        60
# 7191     ScinaxRuber        60
# 7192     ScinaxRuber        60
# 7193     ScinaxRuber        60
# 7194     ScinaxRuber        60
#
# [7195 rows x 26 columns]

# %%
train_df,test_df = train_test_split(df, train_size=0.7,random_state=42)

train_df = train_df.iloc[:,:-1]
train_df = train_df.reset_index(drop=True)

train_x = train_df.iloc[:,:-3]
train_y = train_df.iloc[:,-3:]
train_y_Family = train_df.iloc[:,-3]
train_y_Genus = train_df.iloc[:,-2]
train_y_Species = train_df.iloc[:,-1]

test_df = test_df.iloc[:,:-1]
test_df = test_df.reset_index(drop=True)

test_x = test_df.iloc[:,:-3]
test_y = test_df.iloc[:, -3:]
test_y_Family = test_df.iloc[:,-3]
test_y_Genus = test_df.iloc[:,-2]
test_y_Species = test_df.iloc[:,-1]

# %% [markdown]
# ### (b) Each instance has three labels: Families, Genus, and Species. Each of the labels has multiple classes. We wish to solve a multi-class and multi-label problem. One of the most important approaches to multi-label classification is to train a classifier for each label (binary relevance). We first try this approach.

# %% [markdown]
# ### i. Research exact match and hamming score/ loss methods for evaluating multilabel classification and use them in evaluating the classifiers in this problem.

# %% [markdown]
# Exact Match Metric: This metric indicates the percentage of samples that have all their labels classified correctly.
#
# Hamming Loss Metric: This metric considers the fraction of labels that are incorrectly predicted.

# %%
def exact_match_score(y_true, y_pred):
    total_matches = sum(all(true == pred for true, pred in zip(y_true_row, y_pred_row))
                      for y_true_row, y_pred_row in zip(y_true.values, y_pred.values))
    
    match_score = total_matches / len(y_true)
    
    print(f"Exact match score: {match_score:.4f}")
    
    return round(match_score, 4)

def hamming_loss(y_true, y_pred):
    total_errors = sum(np.count_nonzero(y_true_row != y_pred_row) for y_true_row, y_pred_row in zip(y_true.values, y_pred.values))
    total_elements = y_true.size
    
    hamming_loss_value = total_errors / total_elements
    
    print(f"Hamming Loss: {hamming_loss_value:.4f}")
    print(f"Hamming Score: {1 - hamming_loss_value:.4f}")
    
    return round(hamming_loss_value, 4)

def evaluate_classification(train_y, test_y, y_pred_train, y_pred_test):

    print(f"Test data:")
    exactmatch_test = exact_match_score(test_y, y_pred_test)
    hamloss_test = hamming_loss(test_y, y_pred_test)

    return {
        "exact_match_test": exactmatch_test,
        "hamming_loss_test": hamloss_test
    }

# %% [markdown]
# ### ii. Train a SVM for each of the labels, using Gaussian kernels and one versus all classifiers. Determine the weight of the SVM penalty and the width of the Gaussian Kernel using 10 fold cross validation. You are welcome to try to solve the problem with both standardized and raw attributes and report the results.

# %%
def initialize_prediction_data(columns):
    return pd.DataFrame(columns=columns)

def print_cv_results(grid_search, col):
    print("CV Score (Mean), CV Score (Std) for Parameters")
    
    for params, mean_score, std_score in zip(grid_search.cv_results_['params'],
                                             grid_search.cv_results_['mean_test_score'],
                                             grid_search.cv_results_['std_test_score']):
        print(f"Mean Score: {mean_score:.4f} with Std.: {std_score:.4f} for parameters: {params}")

def SVM_Classifier(X_train, X_test, y_train_now, col, classifier):
    
    if(classifier == 'svm' or classifier == 'std'):
        parameters = {"C": np.logspace(-5, 4, 10), "gamma": np.logspace(-5, 4, 10)}
        svc = SVC(kernel="rbf", decision_function_shape='ovr')
    else:
        parameters = {"C": np.logspace(-5, 4, 10)}
        svc = LinearSVC(penalty='l1',dual = False)
        
    grid_search = GridSearchCV(estimator=svc, param_grid=parameters, cv=StratifiedKFold(10, random_state=42, shuffle=True), n_jobs=-1)
    grid_search.fit(X_train, y_train_now)
    
    print_cv_results(grid_search, col)

    best_estimator = grid_search.best_estimator_
    
    y_train_predict = best_estimator.predict(X_train)
    
    y_test_predict = best_estimator.predict(X_test)
    
    
    if(classifier == 'svm'):
        y_pred_train_svm[col] = y_train_predict
        y_pred_test_svm[col] = y_test_predict
    elif(classifier == 'std'):
        y_pred_train_std[col] = y_train_predict
        y_pred_test_std[col] = y_test_predict
    else:
        y_pred_train_l1[col] = y_train_predict
        y_pred_test_l1[col] = y_test_predict
   
    print(f"Best parameters: {grid_search.best_params_}")

# %%
y_pred_test_svm = initialize_prediction_data(test_y.columns)
y_pred_train_svm = initialize_prediction_data(train_y.columns)

# %%
SVM_Classifier(train_x, test_x, train_y_Family , 'Family', 'svm')
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 0.0001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 0.001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 0.01}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 0.1}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 1.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 10.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 0.0001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 0.001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 0.01}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 0.1}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 1.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 10.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 0.0001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 0.001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 0.01}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 0.1}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 1.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 10.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 0.0001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 0.001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 0.01}
# Mean Score: 0.6201 with Std.: 0.0052 for parameters: {'C': 0.01, 'gamma': 0.1}
# Mean Score: 0.8600 with Std.: 0.0109 for parameters: {'C': 0.01, 'gamma': 1.0}
# Mean Score: 0.7834 with Std.: 0.0105 for parameters: {'C': 0.01, 'gamma': 10.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.1, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.1, 'gamma': 0.0001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.1, 'gamma': 0.001}
# Mean Score: 0.6416 with Std.: 0.0086 for parameters: {'C': 0.1, 'gamma': 0.01}
# Mean Score: 0.8715 with Std.: 0.0078 for parameters: {'C': 0.1, 'gamma': 0.1}
# Mean Score: 0.9607 with Std.: 0.0077 for parameters: {'C': 0.1, 'gamma': 1.0}
# Mean Score: 0.9716 with Std.: 0.0095 for parameters: {'C': 0.1, 'gamma': 10.0}
# Mean Score: 0.7073 with Std.: 0.0079 for parameters: {'C': 0.1, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.1, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.1, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1.0, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.6430 with Std.: 0.0092 for parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.8725 with Std.: 0.0055 for parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.9428 with Std.: 0.0054 for parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.9863 with Std.: 0.0044 for parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.9863 with Std.: 0.0072 for parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.7853 with Std.: 0.0158 for parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.6181 with Std.: 0.0030 for parameters: {'C': 1.0, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1.0, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 10.0, 'gamma': 1e-05}
# Mean Score: 0.6432 with Std.: 0.0092 for parameters: {'C': 10.0, 'gamma': 0.0001}
# Mean Score: 0.8725 with Std.: 0.0045 for parameters: {'C': 10.0, 'gamma': 0.001}
# Mean Score: 0.9323 with Std.: 0.0048 for parameters: {'C': 10.0, 'gamma': 0.01}
# Mean Score: 0.9678 with Std.: 0.0086 for parameters: {'C': 10.0, 'gamma': 0.1}
# Mean Score: 0.9907 with Std.: 0.0040 for parameters: {'C': 10.0, 'gamma': 1.0}
# Mean Score: 0.9867 with Std.: 0.0068 for parameters: {'C': 10.0, 'gamma': 10.0}
# Mean Score: 0.7957 with Std.: 0.0161 for parameters: {'C': 10.0, 'gamma': 100.0}
# Mean Score: 0.6221 with Std.: 0.0039 for parameters: {'C': 10.0, 'gamma': 1000.0}
# Mean Score: 0.6104 with Std.: 0.0011 for parameters: {'C': 10.0, 'gamma': 10000.0}
# Mean Score: 0.6430 with Std.: 0.0092 for parameters: {'C': 100.0, 'gamma': 1e-05}
# Mean Score: 0.8727 with Std.: 0.0043 for parameters: {'C': 100.0, 'gamma': 0.0001}
# Mean Score: 0.9295 with Std.: 0.0048 for parameters: {'C': 100.0, 'gamma': 0.001}
# Mean Score: 0.9492 with Std.: 0.0080 for parameters: {'C': 100.0, 'gamma': 0.01}
# Mean Score: 0.9841 with Std.: 0.0052 for parameters: {'C': 100.0, 'gamma': 0.1}
# Mean Score: 0.9921 with Std.: 0.0042 for parameters: {'C': 100.0, 'gamma': 1.0}
# Mean Score: 0.9867 with Std.: 0.0068 for parameters: {'C': 100.0, 'gamma': 10.0}
# Mean Score: 0.7957 with Std.: 0.0161 for parameters: {'C': 100.0, 'gamma': 100.0}
# Mean Score: 0.6221 with Std.: 0.0039 for parameters: {'C': 100.0, 'gamma': 1000.0}
# Mean Score: 0.6104 with Std.: 0.0011 for parameters: {'C': 100.0, 'gamma': 10000.0}
# Mean Score: 0.8725 with Std.: 0.0039 for parameters: {'C': 1000.0, 'gamma': 1e-05}
# Mean Score: 0.9287 with Std.: 0.0049 for parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.9448 with Std.: 0.0067 for parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.9722 with Std.: 0.0093 for parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.9869 with Std.: 0.0053 for parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.9919 with Std.: 0.0044 for parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.9867 with Std.: 0.0068 for parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.7957 with Std.: 0.0161 for parameters: {'C': 1000.0, 'gamma': 100.0}
# Mean Score: 0.6221 with Std.: 0.0039 for parameters: {'C': 1000.0, 'gamma': 1000.0}
# Mean Score: 0.6104 with Std.: 0.0011 for parameters: {'C': 1000.0, 'gamma': 10000.0}
# Mean Score: 0.9293 with Std.: 0.0052 for parameters: {'C': 10000.0, 'gamma': 1e-05}
# Mean Score: 0.9432 with Std.: 0.0063 for parameters: {'C': 10000.0, 'gamma': 0.0001}
# Mean Score: 0.9551 with Std.: 0.0101 for parameters: {'C': 10000.0, 'gamma': 0.001}
# Mean Score: 0.9831 with Std.: 0.0050 for parameters: {'C': 10000.0, 'gamma': 0.01}
# Mean Score: 0.9877 with Std.: 0.0049 for parameters: {'C': 10000.0, 'gamma': 0.1}
# Mean Score: 0.9919 with Std.: 0.0044 for parameters: {'C': 10000.0, 'gamma': 1.0}
# Mean Score: 0.9867 with Std.: 0.0068 for parameters: {'C': 10000.0, 'gamma': 10.0}
# Mean Score: 0.7957 with Std.: 0.0161 for parameters: {'C': 10000.0, 'gamma': 100.0}
# Mean Score: 0.6221 with Std.: 0.0039 for parameters: {'C': 10000.0, 'gamma': 1000.0}
# Mean Score: 0.6104 with Std.: 0.0011 for parameters: {'C': 10000.0, 'gamma': 10000.0}
# Best parameters: {'C': 100.0, 'gamma': 1.0}

# %%
SVM_Classifier(train_x, test_x, train_y_Genus , 'Genus', 'svm')
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.0001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.01}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.1}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 10.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.0001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.01}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.1}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 10.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.0001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.01}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.1}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 10.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.0001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.01}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.1}
# Mean Score: 0.7903 with Std.: 0.0035 for parameters: {'C': 0.01, 'gamma': 1.0}
# Mean Score: 0.7206 with Std.: 0.0086 for parameters: {'C': 0.01, 'gamma': 10.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 0.0001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 0.001}
# Mean Score: 0.5772 with Std.: 0.0014 for parameters: {'C': 0.1, 'gamma': 0.01}
# Mean Score: 0.8284 with Std.: 0.0061 for parameters: {'C': 0.1, 'gamma': 0.1}
# Mean Score: 0.9361 with Std.: 0.0044 for parameters: {'C': 0.1, 'gamma': 1.0}
# Mean Score: 0.9118 with Std.: 0.0091 for parameters: {'C': 0.1, 'gamma': 10.0}
# Mean Score: 0.6700 with Std.: 0.0118 for parameters: {'C': 0.1, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.5776 with Std.: 0.0020 for parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.8280 with Std.: 0.0065 for parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.9349 with Std.: 0.0051 for parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.9849 with Std.: 0.0039 for parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.9784 with Std.: 0.0052 for parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.7403 with Std.: 0.0102 for parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.5826 with Std.: 0.0030 for parameters: {'C': 1.0, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 10.0, 'gamma': 1e-05}
# Mean Score: 0.5776 with Std.: 0.0020 for parameters: {'C': 10.0, 'gamma': 0.0001}
# Mean Score: 0.8276 with Std.: 0.0062 for parameters: {'C': 10.0, 'gamma': 0.001}
# Mean Score: 0.9325 with Std.: 0.0045 for parameters: {'C': 10.0, 'gamma': 0.01}
# Mean Score: 0.9752 with Std.: 0.0039 for parameters: {'C': 10.0, 'gamma': 0.1}
# Mean Score: 0.9889 with Std.: 0.0035 for parameters: {'C': 10.0, 'gamma': 1.0}
# Mean Score: 0.9807 with Std.: 0.0038 for parameters: {'C': 10.0, 'gamma': 10.0}
# Mean Score: 0.7558 with Std.: 0.0085 for parameters: {'C': 10.0, 'gamma': 100.0}
# Mean Score: 0.5852 with Std.: 0.0046 for parameters: {'C': 10.0, 'gamma': 1000.0}
# Mean Score: 0.5761 with Std.: 0.0013 for parameters: {'C': 10.0, 'gamma': 10000.0}
# Mean Score: 0.5776 with Std.: 0.0020 for parameters: {'C': 100.0, 'gamma': 1e-05}
# Mean Score: 0.8274 with Std.: 0.0061 for parameters: {'C': 100.0, 'gamma': 0.0001}
# Mean Score: 0.9321 with Std.: 0.0047 for parameters: {'C': 100.0, 'gamma': 0.001}
# Mean Score: 0.9615 with Std.: 0.0039 for parameters: {'C': 100.0, 'gamma': 0.01}
# Mean Score: 0.9863 with Std.: 0.0053 for parameters: {'C': 100.0, 'gamma': 0.1}
# Mean Score: 0.9897 with Std.: 0.0050 for parameters: {'C': 100.0, 'gamma': 1.0}
# Mean Score: 0.9807 with Std.: 0.0038 for parameters: {'C': 100.0, 'gamma': 10.0}
# Mean Score: 0.7558 with Std.: 0.0085 for parameters: {'C': 100.0, 'gamma': 100.0}
# Mean Score: 0.5852 with Std.: 0.0046 for parameters: {'C': 100.0, 'gamma': 1000.0}
# Mean Score: 0.5761 with Std.: 0.0013 for parameters: {'C': 100.0, 'gamma': 10000.0}
# Mean Score: 0.8274 with Std.: 0.0061 for parameters: {'C': 1000.0, 'gamma': 1e-05}
# Mean Score: 0.9319 with Std.: 0.0047 for parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.9593 with Std.: 0.0047 for parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.9764 with Std.: 0.0053 for parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.9861 with Std.: 0.0044 for parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.9895 with Std.: 0.0049 for parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.9807 with Std.: 0.0038 for parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.7558 with Std.: 0.0085 for parameters: {'C': 1000.0, 'gamma': 100.0}
# Mean Score: 0.5852 with Std.: 0.0046 for parameters: {'C': 1000.0, 'gamma': 1000.0}
# Mean Score: 0.5761 with Std.: 0.0013 for parameters: {'C': 1000.0, 'gamma': 10000.0}
# Mean Score: 0.9321 with Std.: 0.0047 for parameters: {'C': 10000.0, 'gamma': 1e-05}
# Mean Score: 0.9593 with Std.: 0.0047 for parameters: {'C': 10000.0, 'gamma': 0.0001}
# Mean Score: 0.9708 with Std.: 0.0052 for parameters: {'C': 10000.0, 'gamma': 0.001}
# Mean Score: 0.9841 with Std.: 0.0067 for parameters: {'C': 10000.0, 'gamma': 0.01}
# Mean Score: 0.9857 with Std.: 0.0046 for parameters: {'C': 10000.0, 'gamma': 0.1}
# Mean Score: 0.9895 with Std.: 0.0049 for parameters: {'C': 10000.0, 'gamma': 1.0}
# Mean Score: 0.9807 with Std.: 0.0038 for parameters: {'C': 10000.0, 'gamma': 10.0}
# Mean Score: 0.7558 with Std.: 0.0085 for parameters: {'C': 10000.0, 'gamma': 100.0}
# Mean Score: 0.5852 with Std.: 0.0046 for parameters: {'C': 10000.0, 'gamma': 1000.0}
# Mean Score: 0.5761 with Std.: 0.0013 for parameters: {'C': 10000.0, 'gamma': 10000.0}
# Best parameters: {'C': 100.0, 'gamma': 1.0}

# %%
SVM_Classifier(train_x, test_x, train_y_Species , 'Species', 'svm')
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.0001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.01}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.1}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 10.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.0001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.01}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.1}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 10.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.0001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.01}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.1}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 10.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.0001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.01}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.1}
# Mean Score: 0.8215 with Std.: 0.0102 for parameters: {'C': 0.01, 'gamma': 1.0}
# Mean Score: 0.6583 with Std.: 0.0085 for parameters: {'C': 0.01, 'gamma': 10.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 0.0001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 0.001}
# Mean Score: 0.4980 with Std.: 0.0031 for parameters: {'C': 0.1, 'gamma': 0.01}
# Mean Score: 0.8374 with Std.: 0.0087 for parameters: {'C': 0.1, 'gamma': 0.1}
# Mean Score: 0.9394 with Std.: 0.0106 for parameters: {'C': 0.1, 'gamma': 1.0}
# Mean Score: 0.9192 with Std.: 0.0107 for parameters: {'C': 0.1, 'gamma': 10.0}
# Mean Score: 0.5804 with Std.: 0.0069 for parameters: {'C': 0.1, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.5012 with Std.: 0.0041 for parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.8415 with Std.: 0.0076 for parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.9428 with Std.: 0.0111 for parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.9861 with Std.: 0.0039 for parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.9752 with Std.: 0.0041 for parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.6734 with Std.: 0.0137 for parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.4921 with Std.: 0.0015 for parameters: {'C': 1.0, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 10.0, 'gamma': 1e-05}
# Mean Score: 0.5014 with Std.: 0.0044 for parameters: {'C': 10.0, 'gamma': 0.0001}
# Mean Score: 0.8417 with Std.: 0.0076 for parameters: {'C': 10.0, 'gamma': 0.001}
# Mean Score: 0.9418 with Std.: 0.0108 for parameters: {'C': 10.0, 'gamma': 0.01}
# Mean Score: 0.9780 with Std.: 0.0067 for parameters: {'C': 10.0, 'gamma': 0.1}
# Mean Score: 0.9891 with Std.: 0.0041 for parameters: {'C': 10.0, 'gamma': 1.0}
# Mean Score: 0.9770 with Std.: 0.0036 for parameters: {'C': 10.0, 'gamma': 10.0}
# Mean Score: 0.6954 with Std.: 0.0136 for parameters: {'C': 10.0, 'gamma': 100.0}
# Mean Score: 0.4950 with Std.: 0.0028 for parameters: {'C': 10.0, 'gamma': 1000.0}
# Mean Score: 0.4863 with Std.: 0.0009 for parameters: {'C': 10.0, 'gamma': 10000.0}
# Mean Score: 0.5014 with Std.: 0.0044 for parameters: {'C': 100.0, 'gamma': 1e-05}
# Mean Score: 0.8417 with Std.: 0.0076 for parameters: {'C': 100.0, 'gamma': 0.0001}
# Mean Score: 0.9414 with Std.: 0.0109 for parameters: {'C': 100.0, 'gamma': 0.001}
# Mean Score: 0.9746 with Std.: 0.0083 for parameters: {'C': 100.0, 'gamma': 0.01}
# Mean Score: 0.9867 with Std.: 0.0046 for parameters: {'C': 100.0, 'gamma': 0.1}
# Mean Score: 0.9885 with Std.: 0.0042 for parameters: {'C': 100.0, 'gamma': 1.0}
# Mean Score: 0.9770 with Std.: 0.0036 for parameters: {'C': 100.0, 'gamma': 10.0}
# Mean Score: 0.6954 with Std.: 0.0136 for parameters: {'C': 100.0, 'gamma': 100.0}
# Mean Score: 0.4950 with Std.: 0.0028 for parameters: {'C': 100.0, 'gamma': 1000.0}
# Mean Score: 0.4863 with Std.: 0.0009 for parameters: {'C': 100.0, 'gamma': 10000.0}
# Mean Score: 0.8417 with Std.: 0.0076 for parameters: {'C': 1000.0, 'gamma': 1e-05}
# Mean Score: 0.9414 with Std.: 0.0109 for parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.9742 with Std.: 0.0084 for parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.9792 with Std.: 0.0055 for parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.9863 with Std.: 0.0054 for parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.9885 with Std.: 0.0042 for parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.9770 with Std.: 0.0036 for parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.6954 with Std.: 0.0136 for parameters: {'C': 1000.0, 'gamma': 100.0}
# Mean Score: 0.4950 with Std.: 0.0028 for parameters: {'C': 1000.0, 'gamma': 1000.0}
# Mean Score: 0.4863 with Std.: 0.0009 for parameters: {'C': 1000.0, 'gamma': 10000.0}
# Mean Score: 0.9416 with Std.: 0.0109 for parameters: {'C': 10000.0, 'gamma': 1e-05}
# Mean Score: 0.9742 with Std.: 0.0084 for parameters: {'C': 10000.0, 'gamma': 0.0001}
# Mean Score: 0.9778 with Std.: 0.0056 for parameters: {'C': 10000.0, 'gamma': 0.001}
# Mean Score: 0.9817 with Std.: 0.0063 for parameters: {'C': 10000.0, 'gamma': 0.01}
# Mean Score: 0.9871 with Std.: 0.0051 for parameters: {'C': 10000.0, 'gamma': 0.1}
# Mean Score: 0.9885 with Std.: 0.0042 for parameters: {'C': 10000.0, 'gamma': 1.0}
# Mean Score: 0.9770 with Std.: 0.0036 for parameters: {'C': 10000.0, 'gamma': 10.0}
# Mean Score: 0.6954 with Std.: 0.0136 for parameters: {'C': 10000.0, 'gamma': 100.0}
# Mean Score: 0.4950 with Std.: 0.0028 for parameters: {'C': 10000.0, 'gamma': 1000.0}
# Mean Score: 0.4863 with Std.: 0.0009 for parameters: {'C': 10000.0, 'gamma': 10000.0}
# Best parameters: {'C': 10.0, 'gamma': 1.0}

# %%
evaluation_results = evaluate_classification(train_y, test_y, y_pred_train_svm, y_pred_test_svm)

svm_test_exactmatch = evaluation_results["exact_match_test"]
svm_test_hamloss = evaluation_results["hamming_loss_test"]
# Out:
# Test data:
# Exact match score: 0.9861
# Hamming Loss: 0.0083
# Hamming Score: 0.9917

# %% [markdown]
# ## with standardized data

# %%
# standardizing data

stdScaler=StandardScaler()
train_x_std = stdScaler.fit_transform(train_x)
test_x_std = stdScaler.transform(test_x)

# %%
y_pred_test_std = initialize_prediction_data(test_y.columns)
y_pred_train_std = initialize_prediction_data(train_y.columns)

# %%
SVM_Classifier(train_x_std, test_x_std, train_y_Family , 'Family', 'std')
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 0.0001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 0.001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 0.01}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 0.1}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 1.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 10.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1e-05, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 0.0001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 0.001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 0.01}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 0.1}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 1.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 10.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.0001, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 0.0001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 0.001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 0.01}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 0.1}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 1.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 10.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.001, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 0.0001}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 0.001}
# Mean Score: 0.8364 with Std.: 0.0091 for parameters: {'C': 0.01, 'gamma': 0.01}
# Mean Score: 0.8550 with Std.: 0.0063 for parameters: {'C': 0.01, 'gamma': 0.1}
# Mean Score: 0.6255 with Std.: 0.0035 for parameters: {'C': 0.01, 'gamma': 1.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 10.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.01, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.1, 'gamma': 1e-05}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.1, 'gamma': 0.0001}
# Mean Score: 0.8336 with Std.: 0.0097 for parameters: {'C': 0.1, 'gamma': 0.001}
# Mean Score: 0.9460 with Std.: 0.0068 for parameters: {'C': 0.1, 'gamma': 0.01}
# Mean Score: 0.9714 with Std.: 0.0064 for parameters: {'C': 0.1, 'gamma': 0.1}
# Mean Score: 0.7365 with Std.: 0.0106 for parameters: {'C': 0.1, 'gamma': 1.0}
# Mean Score: 0.6110 with Std.: 0.0013 for parameters: {'C': 0.1, 'gamma': 10.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.1, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.1, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 0.1, 'gamma': 10000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1.0, 'gamma': 1e-05}
# Mean Score: 0.8330 with Std.: 0.0089 for parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.9373 with Std.: 0.0069 for parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.9718 with Std.: 0.0051 for parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.9881 with Std.: 0.0064 for parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.9059 with Std.: 0.0118 for parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.6519 with Std.: 0.0064 for parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.6112 with Std.: 0.0016 for parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1.0, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1.0, 'gamma': 10000.0}
# Mean Score: 0.8332 with Std.: 0.0088 for parameters: {'C': 10.0, 'gamma': 1e-05}
# Mean Score: 0.9349 with Std.: 0.0070 for parameters: {'C': 10.0, 'gamma': 0.0001}
# Mean Score: 0.9508 with Std.: 0.0069 for parameters: {'C': 10.0, 'gamma': 0.001}
# Mean Score: 0.9873 with Std.: 0.0053 for parameters: {'C': 10.0, 'gamma': 0.01}
# Mean Score: 0.9893 with Std.: 0.0063 for parameters: {'C': 10.0, 'gamma': 0.1}
# Mean Score: 0.9106 with Std.: 0.0109 for parameters: {'C': 10.0, 'gamma': 1.0}
# Mean Score: 0.6636 with Std.: 0.0065 for parameters: {'C': 10.0, 'gamma': 10.0}
# Mean Score: 0.6114 with Std.: 0.0017 for parameters: {'C': 10.0, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 10.0, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 10.0, 'gamma': 10000.0}
# Mean Score: 0.9341 with Std.: 0.0065 for parameters: {'C': 100.0, 'gamma': 1e-05}
# Mean Score: 0.9448 with Std.: 0.0069 for parameters: {'C': 100.0, 'gamma': 0.0001}
# Mean Score: 0.9756 with Std.: 0.0084 for parameters: {'C': 100.0, 'gamma': 0.001}
# Mean Score: 0.9895 with Std.: 0.0058 for parameters: {'C': 100.0, 'gamma': 0.01}
# Mean Score: 0.9895 with Std.: 0.0064 for parameters: {'C': 100.0, 'gamma': 0.1}
# Mean Score: 0.9106 with Std.: 0.0109 for parameters: {'C': 100.0, 'gamma': 1.0}
# Mean Score: 0.6636 with Std.: 0.0065 for parameters: {'C': 100.0, 'gamma': 10.0}
# Mean Score: 0.6114 with Std.: 0.0017 for parameters: {'C': 100.0, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 100.0, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 100.0, 'gamma': 10000.0}
# Mean Score: 0.9438 with Std.: 0.0064 for parameters: {'C': 1000.0, 'gamma': 1e-05}
# Mean Score: 0.9553 with Std.: 0.0094 for parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.9835 with Std.: 0.0050 for parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.9903 with Std.: 0.0043 for parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.9895 with Std.: 0.0064 for parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.9106 with Std.: 0.0109 for parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.6636 with Std.: 0.0065 for parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.6114 with Std.: 0.0017 for parameters: {'C': 1000.0, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1000.0, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 1000.0, 'gamma': 10000.0}
# Mean Score: 0.9492 with Std.: 0.0104 for parameters: {'C': 10000.0, 'gamma': 1e-05}
# Mean Score: 0.9726 with Std.: 0.0089 for parameters: {'C': 10000.0, 'gamma': 0.0001}
# Mean Score: 0.9849 with Std.: 0.0043 for parameters: {'C': 10000.0, 'gamma': 0.001}
# Mean Score: 0.9903 with Std.: 0.0043 for parameters: {'C': 10000.0, 'gamma': 0.01}
# Mean Score: 0.9895 with Std.: 0.0064 for parameters: {'C': 10000.0, 'gamma': 0.1}
# Mean Score: 0.9106 with Std.: 0.0109 for parameters: {'C': 10000.0, 'gamma': 1.0}
# Mean Score: 0.6636 with Std.: 0.0065 for parameters: {'C': 10000.0, 'gamma': 10.0}
# Mean Score: 0.6114 with Std.: 0.0017 for parameters: {'C': 10000.0, 'gamma': 100.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 10000.0, 'gamma': 1000.0}
# Mean Score: 0.6102 with Std.: 0.0008 for parameters: {'C': 10000.0, 'gamma': 10000.0}
# Best parameters: {'C': 1000.0, 'gamma': 0.01}

# %%
SVM_Classifier(train_x_std, test_x_std, train_y_Genus , 'Genus', 'std')
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.0001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.01}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.1}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 10.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.0001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.01}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.1}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 10.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.0001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.01}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.1}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 10.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.0001}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.001}
# Mean Score: 0.7869 with Std.: 0.0037 for parameters: {'C': 0.01, 'gamma': 0.01}
# Mean Score: 0.7776 with Std.: 0.0082 for parameters: {'C': 0.01, 'gamma': 0.1}
# Mean Score: 0.5896 with Std.: 0.0040 for parameters: {'C': 0.01, 'gamma': 1.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 10.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 0.0001}
# Mean Score: 0.7840 with Std.: 0.0029 for parameters: {'C': 0.1, 'gamma': 0.001}
# Mean Score: 0.9144 with Std.: 0.0072 for parameters: {'C': 0.1, 'gamma': 0.01}
# Mean Score: 0.9514 with Std.: 0.0047 for parameters: {'C': 0.1, 'gamma': 0.1}
# Mean Score: 0.7010 with Std.: 0.0094 for parameters: {'C': 0.1, 'gamma': 1.0}
# Mean Score: 0.5770 with Std.: 0.0014 for parameters: {'C': 0.1, 'gamma': 10.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 10000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 1e-05}
# Mean Score: 0.7838 with Std.: 0.0029 for parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.9170 with Std.: 0.0060 for parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.9730 with Std.: 0.0051 for parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.9851 with Std.: 0.0049 for parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.8459 with Std.: 0.0061 for parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.6120 with Std.: 0.0070 for parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.5766 with Std.: 0.0019 for parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 10000.0}
# Mean Score: 0.7838 with Std.: 0.0034 for parameters: {'C': 10.0, 'gamma': 1e-05}
# Mean Score: 0.9162 with Std.: 0.0062 for parameters: {'C': 10.0, 'gamma': 0.0001}
# Mean Score: 0.9601 with Std.: 0.0067 for parameters: {'C': 10.0, 'gamma': 0.001}
# Mean Score: 0.9883 with Std.: 0.0046 for parameters: {'C': 10.0, 'gamma': 0.01}
# Mean Score: 0.9869 with Std.: 0.0044 for parameters: {'C': 10.0, 'gamma': 0.1}
# Mean Score: 0.8590 with Std.: 0.0087 for parameters: {'C': 10.0, 'gamma': 1.0}
# Mean Score: 0.6207 with Std.: 0.0090 for parameters: {'C': 10.0, 'gamma': 10.0}
# Mean Score: 0.5768 with Std.: 0.0017 for parameters: {'C': 10.0, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 10.0, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 10.0, 'gamma': 10000.0}
# Mean Score: 0.9164 with Std.: 0.0060 for parameters: {'C': 100.0, 'gamma': 1e-05}
# Mean Score: 0.9557 with Std.: 0.0073 for parameters: {'C': 100.0, 'gamma': 0.0001}
# Mean Score: 0.9788 with Std.: 0.0044 for parameters: {'C': 100.0, 'gamma': 0.001}
# Mean Score: 0.9873 with Std.: 0.0046 for parameters: {'C': 100.0, 'gamma': 0.01}
# Mean Score: 0.9869 with Std.: 0.0044 for parameters: {'C': 100.0, 'gamma': 0.1}
# Mean Score: 0.8590 with Std.: 0.0087 for parameters: {'C': 100.0, 'gamma': 1.0}
# Mean Score: 0.6207 with Std.: 0.0090 for parameters: {'C': 100.0, 'gamma': 10.0}
# Mean Score: 0.5768 with Std.: 0.0017 for parameters: {'C': 100.0, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 100.0, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 100.0, 'gamma': 10000.0}
# Mean Score: 0.9549 with Std.: 0.0073 for parameters: {'C': 1000.0, 'gamma': 1e-05}
# Mean Score: 0.9726 with Std.: 0.0040 for parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.9839 with Std.: 0.0053 for parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.9871 with Std.: 0.0050 for parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.9869 with Std.: 0.0044 for parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.8590 with Std.: 0.0087 for parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.6207 with Std.: 0.0090 for parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.5768 with Std.: 0.0017 for parameters: {'C': 1000.0, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1000.0, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1000.0, 'gamma': 10000.0}
# Mean Score: 0.9708 with Std.: 0.0044 for parameters: {'C': 10000.0, 'gamma': 1e-05}
# Mean Score: 0.9764 with Std.: 0.0071 for parameters: {'C': 10000.0, 'gamma': 0.0001}
# Mean Score: 0.9825 with Std.: 0.0056 for parameters: {'C': 10000.0, 'gamma': 0.001}
# Mean Score: 0.9871 with Std.: 0.0050 for parameters: {'C': 10000.0, 'gamma': 0.01}
# Mean Score: 0.9869 with Std.: 0.0044 for parameters: {'C': 10000.0, 'gamma': 0.1}
# Mean Score: 0.8590 with Std.: 0.0087 for parameters: {'C': 10000.0, 'gamma': 1.0}
# Mean Score: 0.6207 with Std.: 0.0090 for parameters: {'C': 10000.0, 'gamma': 10.0}
# Mean Score: 0.5768 with Std.: 0.0017 for parameters: {'C': 10000.0, 'gamma': 100.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 10000.0, 'gamma': 1000.0}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 10000.0, 'gamma': 10000.0}
# Best parameters: {'C': 10.0, 'gamma': 0.01}

# %%
SVM_Classifier(train_x_std, test_x_std, train_y_Species , 'Species', 'std')
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.0001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.01}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 0.1}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 10.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1e-05, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.0001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.01}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 0.1}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 10.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.0001, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.0001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.01}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 0.1}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 10.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.001, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.0001}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 0.001}
# Mean Score: 0.7313 with Std.: 0.0105 for parameters: {'C': 0.01, 'gamma': 0.01}
# Mean Score: 0.8124 with Std.: 0.0106 for parameters: {'C': 0.01, 'gamma': 0.1}
# Mean Score: 0.4998 with Std.: 0.0040 for parameters: {'C': 0.01, 'gamma': 1.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 10.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.01, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 1e-05}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 0.0001}
# Mean Score: 0.7571 with Std.: 0.0066 for parameters: {'C': 0.1, 'gamma': 0.001}
# Mean Score: 0.9247 with Std.: 0.0134 for parameters: {'C': 0.1, 'gamma': 0.01}
# Mean Score: 0.9579 with Std.: 0.0068 for parameters: {'C': 0.1, 'gamma': 0.1}
# Mean Score: 0.6279 with Std.: 0.0085 for parameters: {'C': 0.1, 'gamma': 1.0}
# Mean Score: 0.4869 with Std.: 0.0013 for parameters: {'C': 0.1, 'gamma': 10.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 0.1, 'gamma': 10000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 1e-05}
# Mean Score: 0.7577 with Std.: 0.0072 for parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.9261 with Std.: 0.0131 for parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.9766 with Std.: 0.0060 for parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.9829 with Std.: 0.0035 for parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.8237 with Std.: 0.0181 for parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.5189 with Std.: 0.0077 for parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.4869 with Std.: 0.0013 for parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1.0, 'gamma': 10000.0}
# Mean Score: 0.7577 with Std.: 0.0072 for parameters: {'C': 10.0, 'gamma': 1e-05}
# Mean Score: 0.9259 with Std.: 0.0135 for parameters: {'C': 10.0, 'gamma': 0.0001}
# Mean Score: 0.9690 with Std.: 0.0075 for parameters: {'C': 10.0, 'gamma': 0.001}
# Mean Score: 0.9869 with Std.: 0.0058 for parameters: {'C': 10.0, 'gamma': 0.01}
# Mean Score: 0.9847 with Std.: 0.0044 for parameters: {'C': 10.0, 'gamma': 0.1}
# Mean Score: 0.8392 with Std.: 0.0192 for parameters: {'C': 10.0, 'gamma': 1.0}
# Mean Score: 0.5270 with Std.: 0.0083 for parameters: {'C': 10.0, 'gamma': 10.0}
# Mean Score: 0.4869 with Std.: 0.0013 for parameters: {'C': 10.0, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 10.0, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 10.0, 'gamma': 10000.0}
# Mean Score: 0.9257 with Std.: 0.0132 for parameters: {'C': 100.0, 'gamma': 1e-05}
# Mean Score: 0.9676 with Std.: 0.0080 for parameters: {'C': 100.0, 'gamma': 0.0001}
# Mean Score: 0.9817 with Std.: 0.0081 for parameters: {'C': 100.0, 'gamma': 0.001}
# Mean Score: 0.9875 with Std.: 0.0056 for parameters: {'C': 100.0, 'gamma': 0.01}
# Mean Score: 0.9847 with Std.: 0.0044 for parameters: {'C': 100.0, 'gamma': 0.1}
# Mean Score: 0.8392 with Std.: 0.0192 for parameters: {'C': 100.0, 'gamma': 1.0}
# Mean Score: 0.5270 with Std.: 0.0083 for parameters: {'C': 100.0, 'gamma': 10.0}
# Mean Score: 0.4869 with Std.: 0.0013 for parameters: {'C': 100.0, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 100.0, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 100.0, 'gamma': 10000.0}
# Mean Score: 0.9678 with Std.: 0.0079 for parameters: {'C': 1000.0, 'gamma': 1e-05}
# Mean Score: 0.9774 with Std.: 0.0067 for parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.9843 with Std.: 0.0064 for parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.9871 with Std.: 0.0056 for parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.9847 with Std.: 0.0044 for parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.8392 with Std.: 0.0192 for parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.5270 with Std.: 0.0083 for parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.4869 with Std.: 0.0013 for parameters: {'C': 1000.0, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1000.0, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 1000.0, 'gamma': 10000.0}
# Mean Score: 0.9768 with Std.: 0.0070 for parameters: {'C': 10000.0, 'gamma': 1e-05}
# Mean Score: 0.9796 with Std.: 0.0066 for parameters: {'C': 10000.0, 'gamma': 0.0001}
# Mean Score: 0.9843 with Std.: 0.0062 for parameters: {'C': 10000.0, 'gamma': 0.001}
# Mean Score: 0.9871 with Std.: 0.0056 for parameters: {'C': 10000.0, 'gamma': 0.01}
# Mean Score: 0.9847 with Std.: 0.0044 for parameters: {'C': 10000.0, 'gamma': 0.1}
# Mean Score: 0.8392 with Std.: 0.0192 for parameters: {'C': 10000.0, 'gamma': 1.0}
# Mean Score: 0.5270 with Std.: 0.0083 for parameters: {'C': 10000.0, 'gamma': 10.0}
# Mean Score: 0.4869 with Std.: 0.0013 for parameters: {'C': 10000.0, 'gamma': 100.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 10000.0, 'gamma': 1000.0}
# Mean Score: 0.4859 with Std.: 0.0006 for parameters: {'C': 10000.0, 'gamma': 10000.0}
# Best parameters: {'C': 100.0, 'gamma': 0.01}

# %%
evaluation_results = evaluate_classification(train_y, test_y, y_pred_train_std, y_pred_test_std)

std_test_exactmatch = evaluation_results["exact_match_test"]
std_test_hamloss = evaluation_results["hamming_loss_test"]
# Out:
# Test data:
# Exact match score: 0.9792
# Hamming Loss: 0.0113
# Hamming Score: 0.9887

# %% [markdown]
# ### iii. Repeat 1(b)ii with L1-penalized SVMs. Remember to standardize the attributes. Determine the weight of the SVM penalty using 10 fold cross validation.

# %%
y_pred_test_l1 = initialize_prediction_data(test_y.columns)
y_pred_train_l1 = initialize_prediction_data(train_y.columns)

# %%
SVM_Classifier(train_x_std, test_x_std, train_y_Family , 'Family', 'l1')
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.0081 with Std.: 0.0006 for parameters: {'C': 1e-05}
# Mean Score: 0.0081 with Std.: 0.0006 for parameters: {'C': 0.0001}
# Mean Score: 0.8523 with Std.: 0.0103 for parameters: {'C': 0.001}
# Mean Score: 0.9305 with Std.: 0.0095 for parameters: {'C': 0.01}
# Mean Score: 0.9380 with Std.: 0.0078 for parameters: {'C': 0.1}
# Mean Score: 0.9408 with Std.: 0.0078 for parameters: {'C': 1.0}
# Mean Score: 0.9412 with Std.: 0.0076 for parameters: {'C': 10.0}
# Mean Score: 0.9410 with Std.: 0.0075 for parameters: {'C': 100.0}
# Mean Score: 0.9410 with Std.: 0.0075 for parameters: {'C': 1000.0}
# Mean Score: 0.9410 with Std.: 0.0075 for parameters: {'C': 10000.0}
# Best parameters: {'C': 10.0}

# %%
SVM_Classifier(train_x_std, test_x_std, train_y_Genus , 'Genus', 'l1')
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 1e-05}
# Mean Score: 0.5757 with Std.: 0.0006 for parameters: {'C': 0.0001}
# Mean Score: 0.8235 with Std.: 0.0056 for parameters: {'C': 0.001}
# Mean Score: 0.9134 with Std.: 0.0066 for parameters: {'C': 0.01}
# Mean Score: 0.9424 with Std.: 0.0048 for parameters: {'C': 0.1}
# Mean Score: 0.9500 with Std.: 0.0056 for parameters: {'C': 1.0}
# Mean Score: 0.9516 with Std.: 0.0057 for parameters: {'C': 10.0}
# Mean Score: 0.9516 with Std.: 0.0061 for parameters: {'C': 100.0}
# Mean Score: 0.9517 with Std.: 0.0063 for parameters: {'C': 1000.0}
# Mean Score: 0.9517 with Std.: 0.0063 for parameters: {'C': 10000.0}
# Best parameters: {'C': 1000.0}

# %%
SVM_Classifier(train_x_std, test_x_std, train_y_Species , 'Species', 'l1')
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.0898 with Std.: 0.0008 for parameters: {'C': 1e-05}
# Mean Score: 0.0898 with Std.: 0.0008 for parameters: {'C': 0.0001}
# Mean Score: 0.7869 with Std.: 0.0098 for parameters: {'C': 0.001}
# Mean Score: 0.9160 with Std.: 0.0119 for parameters: {'C': 0.01}
# Mean Score: 0.9500 with Std.: 0.0114 for parameters: {'C': 0.1}
# Mean Score: 0.9603 with Std.: 0.0098 for parameters: {'C': 1.0}
# Mean Score: 0.9607 with Std.: 0.0087 for parameters: {'C': 10.0}
# Mean Score: 0.9607 with Std.: 0.0087 for parameters: {'C': 100.0}
# Mean Score: 0.9607 with Std.: 0.0087 for parameters: {'C': 1000.0}
# Mean Score: 0.9607 with Std.: 0.0087 for parameters: {'C': 10000.0}
# Best parameters: {'C': 10.0}

# %%
evaluation_results = evaluate_classification(train_y, test_y, y_pred_train_l1, y_pred_test_l1)

l1_test_exactmatch = evaluation_results["exact_match_test"]
l1_test_hamloss = evaluation_results["hamming_loss_test"]
# Out:
# Test data:
# Exact match score: 0.9125
# Hamming Loss: 0.0570
# Hamming Score: 0.9430

# %% [markdown]
# ### iv. Repeat 1(b)iii by using SMOTE or any other method you know to remedy class imbalance.

# %%
def fit_smote_and_grid_search(X_train_std, X_test_std, y_train_now, y_test_now, col, parameters):
    smote = SMOTE(random_state=42)
    X_train_smote, y_train_smote = smote.fit_resample(X_train_std, y_train_now)
    X_test_smote, y_test_smote = smote.fit_resample(X_test_std, y_test_now)
    
    svc = LinearSVC(penalty='l1', dual=False)
    grid_search = GridSearchCV(estimator=svc, param_grid=parameters, cv=StratifiedKFold(10, random_state=42, shuffle=True), n_jobs=-1)
    grid_search.fit(X_train_smote, y_train_smote)
    
    print_cv_results(grid_search, col)

    classifiers[col] = grid_search.best_estimator_
    
    print(f"Best parameters: {grid_search.best_params_}")
    
    y_pred_train_smote[col] = classifiers[col].predict(X_train_std) 
    y_pred_test_smote[col] = classifiers[col].predict(X_test_std)

# %%
parameters = {"C": np.logspace(1, 5, 5)}

y_pred_test_smote = initialize_prediction_data(test_y.columns)
y_pred_train_smote = initialize_prediction_data(train_y.columns)

classifiers = {}

fit_smote_and_grid_search(train_x_std, test_x_std, train_y_Family, test_y_Family, 'Family', parameters)
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.9516 with Std.: 0.0080 for parameters: {'C': 10.0}
# Mean Score: 0.9515 with Std.: 0.0079 for parameters: {'C': 100.0}
# Mean Score: 0.9516 with Std.: 0.0080 for parameters: {'C': 1000.0}
# Mean Score: 0.9516 with Std.: 0.0080 for parameters: {'C': 10000.0}
# Mean Score: 0.9515 with Std.: 0.0079 for parameters: {'C': 100000.0}
# Best parameters: {'C': 10.0}

# %%
fit_smote_and_grid_search(train_x_std, test_x_std, train_y_Genus, test_y_Genus, 'Genus', parameters)
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.9606 with Std.: 0.0042 for parameters: {'C': 10.0}
# Mean Score: 0.9606 with Std.: 0.0042 for parameters: {'C': 100.0}
# Mean Score: 0.9606 with Std.: 0.0042 for parameters: {'C': 1000.0}
# Mean Score: 0.9606 with Std.: 0.0042 for parameters: {'C': 10000.0}
# Mean Score: 0.9606 with Std.: 0.0042 for parameters: {'C': 100000.0}
# Best parameters: {'C': 1000.0}

# %%
fit_smote_and_grid_search(train_x_std, test_x_std, train_y_Species, test_y_Species, 'Species', parameters)
# Out:
# CV Score (Mean), CV Score (Std) for Parameters
# Mean Score: 0.9631 with Std.: 0.0023 for parameters: {'C': 10.0}
# Mean Score: 0.9632 with Std.: 0.0023 for parameters: {'C': 100.0}
# Mean Score: 0.9632 with Std.: 0.0023 for parameters: {'C': 1000.0}
# Mean Score: 0.9632 with Std.: 0.0023 for parameters: {'C': 10000.0}
# Mean Score: 0.9632 with Std.: 0.0023 for parameters: {'C': 100000.0}
# Best parameters: {'C': 100.0}

# %%
evaluation_results = evaluate_classification(train_y, test_y, y_pred_train_smote, y_pred_test_smote)

smote_test_exactmatch = evaluation_results["exact_match_test"]
smote_test_hamloss = evaluation_results["hamming_loss_test"]
# Out:
# Test data:
# Exact match score: 0.8532
# Hamming Loss: 0.0769
# Hamming Score: 0.9231

# %% [markdown]
# ### Report your conclusions about the classifiers you trained.

# %%
conclusion={}
conclusion['SVM: Gaussian Kernels with Raw Data']={'Exact Match Score':svm_test_exactmatch,
                                                             'Hamming Loss':svm_test_hamloss}

conclusion['SVM: Standardized Data']={'Exact Match Score':std_test_exactmatch,
                                                             'Hamming Loss':std_test_hamloss}

conclusion['SVM: L1-Penalized Standarized Data']={'Exact Match Score':l1_test_exactmatch,
                                                             'Hamming Loss':l1_test_hamloss}

conclusion['SVM: SMOTE L1-Penalized Standarized Data']={'Exact Match Score':smote_test_exactmatch,
                                                             'Hamming Loss':smote_test_hamloss}
conclusion_df=pd.DataFrame(conclusion)
conclusion_df
# Out:
#                    SVM: Gaussian Kernels with Raw Data  \
# Exact Match Score                               0.9861
# Hamming Loss                                    0.0083
#
#                    SVM: Standardized Data  SVM: L1-Penalized Standarized Data  \
# Exact Match Score                  0.9792                              0.9125
# Hamming Loss                       0.0113                              0.0570
#
#                    SVM: SMOTE L1-Penalized Standarized Data
# Exact Match Score                                    0.8532
# Hamming Loss                                         0.0769

# %% [markdown]
# #### Conclusions:
#
# - Exact Match Score is the highest for Gaussian Kernel SVM (with raw data) and lowest for L1-penalized SVM using SMOTE.
#
# - Hamming Loss is lowest for Gaussian Kernel SVM (with raw data) and highest for L1-penalized SVM using SMOTE.
#
# - After balancing classes using SMOTE, compared to unbalanced L1-penalized, the Exact Match Score is lower and Hamming Loss is higher.
#
# - After looking at all the results, the best performing model seems to be the Gaussian Kernel SVM with raw data.

# %% [markdown]
# ### 2. K-Means Clustering on a Multi-Class and Multi-Label Data Set
# ### Monte-Carlo Simulation: Perform the following procedures 50 times, and report the average and standard deviation of the 50 Hamming Distances that you calculate.

# %% [markdown]
# ### (a) Use k-means clustering on the whole Anuran Calls (MFCCs) Data Set (do not split the data into train and test, as we are not performing supervised learning in this exercise). Choose k ∈ {1, 2, . . . , 50} automatically based on one of the methods provided in the slides (CH or Gap Statistics or scree plots or Silhouettes) or any other method you know.
# ### (b) In each cluster, determine which family is the majority by reading the true labels. Repeat for genus and species.

# %%
def calculate_silhouette_score(k, X):
    rand_value = random.randint(0, 900)
    k_means = KMeans(n_clusters=k, random_state=rand_value)
    clusters = k_means.fit_predict(X)
    sil_score = silhouette_score(X, clusters)
    return sil_score

def find_best_k(k_start, k_end, X):
    max_score = -1
    best_k = k_start
    
    for k in range(k_start, k_end + 1):
        sil_score = calculate_silhouette_score(k, X)
        if sil_score > max_score:
            best_k = k
            max_score = sil_score
            
    print('Best k: ', best_k)
    return best_k

def calculate_cluster_majority_labels(optimalK, Act_Y, cluster_label):
    majority_dict = {}
    
    for i in range(optimalK):
        majority_dict[i] = []
        for col in Act_Y.columns:
            majority_dict[i].append(get_majority_label_for_cluster(i, col, Act_Y, cluster_label))
            
    return majority_dict

def get_majority_label_for_cluster(cluster_num, col, Act_Y, cluster_label):
    cluster_i_index = np.where(cluster_label == cluster_num)[0]
    cluster_i_label_values_counts = Act_Y.loc[cluster_i_index, col].value_counts()
    cluster_i_label_max = pd.Series(cluster_i_label_values_counts[
        cluster_i_label_values_counts == max(cluster_i_label_values_counts)
    ]).index[0]
    return cluster_i_label_max

def evaluate_cluster_labels(Act_Y, cluster_label, cluster_majority):
    total_labels, correct_class, temp = 0, 0, 0
    
    for i in range(max(cluster_majority) + 1):
        cluster_i_index = np.where(cluster_label == i)[0]
        
        for row in Act_Y.loc[cluster_i_index].values:
            total, matching = calculate_matching_labels(row, cluster_majority[i])
            temp += (total - matching)
            correct_class += matching
            total_labels += total
    
    hamming_loss = temp / (Act_Y.shape[0] * Act_Y.shape[1])
    hamming_score = correct_class / (Act_Y.shape[0] * Act_Y.shape[1])
    hamming_distance = temp / Act_Y.shape[0]
    
    return {'Hamming_Loss': hamming_loss, 'Hamming_Score': hamming_score, 'Hamming_Distance': hamming_distance}

def calculate_matching_labels(row, majority_labels):
    total = np.size(row == majority_labels)
    matching = np.count_nonzero(row == majority_labels)
    return total, matching

def run_single_iteration(X, Act_Y, k_start, k_end):
    k = find_best_k(k_start, k_end, X)
    clusterer = KMeans(n_clusters=k)
    cluster_label = clusterer.fit_predict(X)
    cluster_majority = calculate_cluster_majority_labels(k, Act_Y, cluster_label)
    
    print('\n Cluster Majority: ')

    cluster_major=pd.DataFrame(cluster_majority,index=['Family','Genus','Species'])
    cluster_major.columns = [f'Cluster {i}' for i in range(len(cluster_major.columns))]
    
    display(cluster_major)
    
    return evaluate_cluster_labels(Act_Y, cluster_label, cluster_majority)

def monte_carlo_simulation(N, k_start, k_end, X, Act_Y):
    score_list = {'Hamming_Loss': [], 'Hamming_Score': [], 'Hamming_Distance': []}
    
    for i in range(N):
        print('\n\nIteration ', i + 1)
        iteration_scores = run_single_iteration(X, Act_Y, k_start, k_end)
        
        print('\nEvaluations:')
        print(pd.Series(iteration_scores))
        
        for metric, value in iteration_scores.items():
            score_list[metric].append(value)
            
    return score_list

# %%
dfx = df.iloc[:,:-4]
dfy = df.iloc[:,-4:-1]

scores = monte_carlo_simulation(50,2,50,dfx,dfy)
# Out:
# Iteration  1
# Best k:  4
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1        Cluster 2  \
# Family             Hylidae         Leptodactylidae  Leptodactylidae
# Genus            Hypsiboas               Adenomera        Adenomera
# Species  HypsiboasCordobae  AdenomeraHylaedactylus   AdenomeraAndre
#
#                     Cluster 3
# Family                Hylidae
# Genus               Hypsiboas
# Species  HypsiboasCinerascens
# Evaluations:
# Hamming_Loss        0.233356
# Hamming_Score       0.766644
# Hamming_Distance    0.700069
# dtype: float64
#
#
# Iteration  2
# Best k:  4
#
#  Cluster Majority:
#                Cluster 0               Cluster 1          Cluster 2  \
# Family   Leptodactylidae         Leptodactylidae            Hylidae
# Genus          Adenomera               Adenomera          Hypsiboas
# Species   AdenomeraAndre  AdenomeraHylaedactylus  HypsiboasCordobae
#
#                   Cluster 3
# Family        Dendrobatidae
# Genus              Ameerega
# Species  Ameeregatrivittata
# Evaluations:
# Hamming_Loss        0.186055
# Hamming_Score       0.813945
# Hamming_Distance    0.558165
# dtype: float64
#
#
# Iteration  3
# Best k:  6
#
#  Cluster Majority:
#                       Cluster 0               Cluster 1        Cluster 2  \
# Family          Leptodactylidae         Leptodactylidae  Leptodactylidae
# Genus                 Adenomera               Adenomera        Adenomera
# Species  AdenomeraHylaedactylus  AdenomeraHylaedactylus   AdenomeraAndre
#
#                  Cluster 3             Cluster 4           Cluster 5
# Family             Hylidae               Hylidae       Dendrobatidae
# Genus            Hypsiboas             Hypsiboas            Ameerega
# Species  HypsiboasCordobae  HypsiboasCinerascens  Ameeregatrivittata
# Evaluations:
# Hamming_Loss        0.199629
# Hamming_Score       0.800371
# Hamming_Distance    0.598888
# dtype: float64
#
#
# Iteration  4
# Best k:  3
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1          Cluster 2
# Family          Leptodactylidae            Hylidae            Hylidae
# Genus                 Adenomera          Hypsiboas          Hypsiboas
# Species  AdenomeraHylaedactylus  HypsiboasCordobae  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.296780
# Hamming_Score       0.703220
# Hamming_Distance    0.890341
# dtype: float64
#
#
# Iteration  5
# Best k:  4
#
#  Cluster Majority:
#                Cluster 0               Cluster 1           Cluster 2  \
# Family   Leptodactylidae         Leptodactylidae       Dendrobatidae
# Genus          Adenomera               Adenomera            Ameerega
# Species   AdenomeraAndre  AdenomeraHylaedactylus  Ameeregatrivittata
#
#                  Cluster 3
# Family             Hylidae
# Genus            Hypsiboas
# Species  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.185916
# Hamming_Score       0.814084
# Hamming_Distance    0.557748
# dtype: float64
#
#
# Iteration  6
# Best k:  4
#
#  Cluster Majority:
#                   Cluster 0        Cluster 1               Cluster 2  \
# Family        Dendrobatidae  Leptodactylidae         Leptodactylidae
# Genus              Ameerega        Adenomera               Adenomera
# Species  Ameeregatrivittata   AdenomeraAndre  AdenomeraHylaedactylus
#
#                  Cluster 3
# Family             Hylidae
# Genus            Hypsiboas
# Species  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.186055
# Hamming_Score       0.813945
# Hamming_Distance    0.558165
# dtype: float64
#
#
# Iteration  7
# Best k:  4
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1               Cluster 2  \
# Family             Hylidae         Leptodactylidae         Leptodactylidae
# Genus            Hypsiboas               Adenomera               Adenomera
# Species  HypsiboasCordobae  AdenomeraHylaedactylus  AdenomeraHylaedactylus
#
#                     Cluster 3
# Family                Hylidae
# Genus               Hypsiboas
# Species  HypsiboasCinerascens
# Evaluations:
# Hamming_Loss        0.285152
# Hamming_Score       0.714848
# Hamming_Distance    0.855455
# dtype: float64
#
#
# Iteration  8
# Best k:  5
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1        Cluster 2  \
# Family          Leptodactylidae            Hylidae  Leptodactylidae
# Genus                 Adenomera          Hypsiboas        Adenomera
# Species  AdenomeraHylaedactylus  HypsiboasCordobae   AdenomeraAndre
#
#                       Cluster 3             Cluster 4
# Family          Leptodactylidae               Hylidae
# Genus                 Adenomera             Hypsiboas
# Species  AdenomeraHylaedactylus  HypsiboasCinerascens
# Evaluations:
# Hamming_Loss        0.234839
# Hamming_Score       0.765161
# Hamming_Distance    0.704517
# dtype: float64
#
#
# Iteration  9
# Best k:  4
#
#  Cluster Majority:
#                  Cluster 0             Cluster 1               Cluster 2  \
# Family             Hylidae               Hylidae         Leptodactylidae
# Genus            Hypsiboas             Hypsiboas               Adenomera
# Species  HypsiboasCordobae  HypsiboasCinerascens  AdenomeraHylaedactylus
#
#                Cluster 3
# Family   Leptodactylidae
# Genus          Adenomera
# Species   AdenomeraAndre
# Evaluations:
# Hamming_Loss        0.233727
# Hamming_Score       0.766273
# Hamming_Distance    0.701181
# dtype: float64
#
#
# Iteration  10
# Best k:  3
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1           Cluster 2
# Family             Hylidae         Leptodactylidae       Dendrobatidae
# Genus            Hypsiboas               Adenomera            Ameerega
# Species  HypsiboasCordobae  AdenomeraHylaedactylus  Ameeregatrivittata
# Evaluations:
# Hamming_Loss        0.238499
# Hamming_Score       0.761501
# Hamming_Distance    0.715497
# dtype: float64
#
#
# Iteration  11
# Best k:  6
#
#  Cluster Majority:
#                   Cluster 0          Cluster 1               Cluster 2  \
# Family        Dendrobatidae            Hylidae         Leptodactylidae
# Genus              Ameerega          Hypsiboas               Adenomera
# Species  Ameeregatrivittata  HypsiboasCordobae  AdenomeraHylaedactylus
#
#                    Cluster 3             Cluster 4               Cluster 5
# Family               Hylidae               Hylidae         Leptodactylidae
# Genus          Leptodactylus             Hypsiboas               Adenomera
# Species  LeptodactylusFuscus  HypsiboasCinerascens  AdenomeraHylaedactylus
# Evaluations:
# Hamming_Loss        0.212601
# Hamming_Score       0.787399
# Hamming_Distance    0.637804
# dtype: float64
#
#
# Iteration  12
# Best k:  5
#
#  Cluster Majority:
#                       Cluster 0        Cluster 1           Cluster 2  \
# Family          Leptodactylidae  Leptodactylidae       Dendrobatidae
# Genus                 Adenomera        Adenomera            Ameerega
# Species  AdenomeraHylaedactylus   AdenomeraAndre  Ameeregatrivittata
#
#                  Cluster 3             Cluster 4
# Family             Hylidae               Hylidae
# Genus            Hypsiboas             Hypsiboas
# Species  HypsiboasCordobae  HypsiboasCinerascens
# Evaluations:
# Hamming_Loss        0.199398
# Hamming_Score       0.800602
# Hamming_Distance    0.598193
# dtype: float64
#
#
# Iteration  13
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1               Cluster 2  \
# Family          Leptodactylidae            Hylidae         Leptodactylidae
# Genus                 Adenomera          Hypsiboas               Adenomera
# Species  AdenomeraHylaedactylus  HypsiboasCordobae  AdenomeraHylaedactylus
#
#                  Cluster 3
# Family             Hylidae
# Genus            Hypsiboas
# Species  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.297892
# Hamming_Score       0.702108
# Hamming_Distance    0.893676
# dtype: float64
#
#
# Iteration  14
# Best k:  3
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1          Cluster 2
# Family             Hylidae         Leptodactylidae            Hylidae
# Genus            Hypsiboas               Adenomera          Hypsiboas
# Species  HypsiboasCordobae  AdenomeraHylaedactylus  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.296780
# Hamming_Score       0.703220
# Hamming_Distance    0.890341
# dtype: float64
#
#
# Iteration  15
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1               Cluster 2  \
# Family          Leptodactylidae            Hylidae         Leptodactylidae
# Genus                 Adenomera          Hypsiboas               Adenomera
# Species  AdenomeraHylaedactylus  HypsiboasCordobae  AdenomeraHylaedactylus
#
#                  Cluster 3
# Family             Hylidae
# Genus            Hypsiboas
# Species  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.297985
# Hamming_Score       0.702015
# Hamming_Distance    0.893954
# dtype: float64
#
#
# Iteration  16
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1             Cluster 2  \
# Family          Leptodactylidae            Hylidae               Hylidae
# Genus                 Adenomera          Hypsiboas             Hypsiboas
# Species  AdenomeraHylaedactylus  HypsiboasCordobae  HypsiboasCinerascens
#
#                Cluster 3
# Family   Leptodactylidae
# Genus          Adenomera
# Species   AdenomeraAndre
# Evaluations:
# Hamming_Loss        0.233727
# Hamming_Score       0.766273
# Hamming_Distance    0.701181
# dtype: float64
#
#
# Iteration  17
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1        Cluster 2  \
# Family          Leptodactylidae            Hylidae  Leptodactylidae
# Genus                 Adenomera          Hypsiboas        Adenomera
# Species  AdenomeraHylaedactylus  HypsiboasCordobae   AdenomeraAndre
#
#                     Cluster 3
# Family                Hylidae
# Genus               Hypsiboas
# Species  HypsiboasCinerascens
# Evaluations:
# Hamming_Loss        0.233727
# Hamming_Score       0.766273
# Hamming_Distance    0.701181
# dtype: float64
#
#
# Iteration  18
# Best k:  6
#
#  Cluster Majority:
#                     Cluster 0               Cluster 1          Cluster 2  \
# Family                Hylidae         Leptodactylidae            Hylidae
# Genus               Hypsiboas               Adenomera          Hypsiboas
# Species  HypsiboasCinerascens  AdenomeraHylaedactylus  HypsiboasCordobae
#
#                       Cluster 3           Cluster 4        Cluster 5
# Family          Leptodactylidae       Dendrobatidae  Leptodactylidae
# Genus                 Adenomera            Ameerega        Adenomera
# Species  AdenomeraHylaedactylus  Ameeregatrivittata   AdenomeraAndre
# Evaluations:
# Hamming_Loss        0.168265
# Hamming_Score       0.831735
# Hamming_Distance    0.504795
# dtype: float64
#
#
# Iteration  19
# Best k:  4
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1           Cluster 2  \
# Family             Hylidae         Leptodactylidae       Dendrobatidae
# Genus            Hypsiboas               Adenomera            Ameerega
# Species  HypsiboasCordobae  AdenomeraHylaedactylus  Ameeregatrivittata
#
#                Cluster 3
# Family   Leptodactylidae
# Genus          Adenomera
# Species   AdenomeraAndre
# Evaluations:
# Hamming_Loss        0.185916
# Hamming_Score       0.814084
# Hamming_Distance    0.557748
# dtype: float64
#
#
# Iteration  20
# Best k:  4
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1           Cluster 2  \
# Family             Hylidae         Leptodactylidae       Dendrobatidae
# Genus            Hypsiboas               Adenomera            Ameerega
# Species  HypsiboasCordobae  AdenomeraHylaedactylus  Ameeregatrivittata
#
#                Cluster 3
# Family   Leptodactylidae
# Genus          Adenomera
# Species   AdenomeraAndre
# Evaluations:
# Hamming_Loss        0.185916
# Hamming_Score       0.814084
# Hamming_Distance    0.557748
# dtype: float64
#
#
# Iteration  21
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1           Cluster 2  \
# Family          Leptodactylidae            Hylidae       Dendrobatidae
# Genus                 Adenomera          Hypsiboas            Ameerega
# Species  AdenomeraHylaedactylus  HypsiboasCordobae  Ameeregatrivittata
#
#                Cluster 3
# Family   Leptodactylidae
# Genus          Adenomera
# Species   AdenomeraAndre
# Evaluations:
# Hamming_Loss        0.185916
# Hamming_Score       0.814084
# Hamming_Distance    0.557748
# dtype: float64
#
#
# Iteration  22
# Best k:  5
#
#  Cluster Majority:
#                Cluster 0               Cluster 1          Cluster 2  \
# Family   Leptodactylidae         Leptodactylidae            Hylidae
# Genus          Adenomera               Adenomera          Hypsiboas
# Species   AdenomeraAndre  AdenomeraHylaedactylus  HypsiboasCordobae
#
#                  Cluster 3               Cluster 4
# Family             Hylidae         Leptodactylidae
# Genus            Hypsiboas               Adenomera
# Species  HypsiboasCordobae  AdenomeraHylaedactylus
# Evaluations:
# Hamming_Loss        0.246606
# Hamming_Score       0.753394
# Hamming_Distance    0.739819
# dtype: float64
#
#
# Iteration  23
# Best k:  4
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1             Cluster 2  \
# Family             Hylidae         Leptodactylidae               Hylidae
# Genus            Hypsiboas               Adenomera             Hypsiboas
# Species  HypsiboasCordobae  AdenomeraHylaedactylus  HypsiboasCinerascens
#
#                Cluster 3
# Family   Leptodactylidae
# Genus          Adenomera
# Species   AdenomeraAndre
# Evaluations:
# Hamming_Loss        0.233681
# Hamming_Score       0.766319
# Hamming_Distance    0.701042
# dtype: float64
#
#
# Iteration  24
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0             Cluster 1          Cluster 2  \
# Family          Leptodactylidae               Hylidae            Hylidae
# Genus                 Adenomera             Hypsiboas          Hypsiboas
# Species  AdenomeraHylaedactylus  HypsiboasCinerascens  HypsiboasCordobae
#
#                   Cluster 3
# Family        Dendrobatidae
# Genus              Ameerega
# Species  Ameeregatrivittata
# Evaluations:
# Hamming_Loss        0.215752
# Hamming_Score       0.784248
# Hamming_Distance    0.647255
# dtype: float64
#
#
# Iteration  25
# Best k:  5
#
#  Cluster Majority:
#                       Cluster 0           Cluster 1             Cluster 2  \
# Family          Leptodactylidae       Dendrobatidae               Hylidae
# Genus                 Adenomera            Ameerega             Hypsiboas
# Species  AdenomeraHylaedactylus  Ameeregatrivittata  HypsiboasCinerascens
#
#                       Cluster 3          Cluster 4
# Family          Leptodactylidae            Hylidae
# Genus                 Adenomera          Hypsiboas
# Species  AdenomeraHylaedactylus  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.216493
# Hamming_Score       0.783507
# Hamming_Distance    0.649479
# dtype: float64
#
#
# Iteration  26
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1               Cluster 2  \
# Family          Leptodactylidae            Hylidae         Leptodactylidae
# Genus                 Adenomera          Hypsiboas               Adenomera
# Species  AdenomeraHylaedactylus  HypsiboasCordobae  AdenomeraHylaedactylus
#
#                       Cluster 3
# Family          Leptodactylidae
# Genus                 Adenomera
# Species  AdenomeraHylaedactylus
# Evaluations:
# Hamming_Loss        0.301969
# Hamming_Score       0.698031
# Hamming_Distance    0.905907
# dtype: float64
#
#
# Iteration  27
# Best k:  3
#
#  Cluster Majority:
#                       Cluster 0           Cluster 1          Cluster 2
# Family          Leptodactylidae       Dendrobatidae            Hylidae
# Genus                 Adenomera            Ameerega          Hypsiboas
# Species  AdenomeraHylaedactylus  Ameeregatrivittata  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.238638
# Hamming_Score       0.761362
# Hamming_Distance    0.715914
# dtype: float64
#
#
# Iteration  28
# Best k:  6
#
#  Cluster Majority:
#                       Cluster 0             Cluster 1        Cluster 2  \
# Family          Leptodactylidae               Hylidae  Leptodactylidae
# Genus                 Adenomera             Hypsiboas        Adenomera
# Species  AdenomeraHylaedactylus  HypsiboasCinerascens   AdenomeraAndre
#
#                    Cluster 3          Cluster 4        Cluster 5
# Family       Leptodactylidae            Hylidae  Leptodactylidae
# Genus          Leptodactylus          Hypsiboas        Adenomera
# Species  LeptodactylusFuscus  HypsiboasCordobae   AdenomeraAndre
# Evaluations:
# Hamming_Loss        0.187167
# Hamming_Score       0.812833
# Hamming_Distance    0.561501
# dtype: float64
#
#
# Iteration  29
# Best k:  6
#
#  Cluster Majority:
#                       Cluster 0        Cluster 1          Cluster 2  \
# Family          Leptodactylidae  Leptodactylidae            Hylidae
# Genus                 Adenomera        Adenomera          Hypsiboas
# Species  AdenomeraHylaedactylus   AdenomeraAndre  HypsiboasCordobae
#
#                     Cluster 3        Cluster 4            Cluster 5
# Family                Hylidae  Leptodactylidae      Leptodactylidae
# Genus               Hypsiboas        Adenomera        Leptodactylus
# Species  HypsiboasCinerascens   AdenomeraAndre  LeptodactylusFuscus
# Evaluations:
# Hamming_Loss        0.187306
# Hamming_Score       0.812694
# Hamming_Distance    0.561918
# dtype: float64
#
#
# Iteration  30
# Best k:  4
#
#  Cluster Majority:
#                Cluster 0               Cluster 1          Cluster 2  \
# Family   Leptodactylidae         Leptodactylidae            Hylidae
# Genus          Adenomera               Adenomera          Hypsiboas
# Species   AdenomeraAndre  AdenomeraHylaedactylus  HypsiboasCordobae
#
#                     Cluster 3
# Family                Hylidae
# Genus               Hypsiboas
# Species  HypsiboasCinerascens
# Evaluations:
# Hamming_Loss        0.233403
# Hamming_Score       0.766597
# Hamming_Distance    0.700208
# dtype: float64
#
#
# Iteration  31
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0           Cluster 1             Cluster 2  \
# Family          Leptodactylidae       Dendrobatidae               Hylidae
# Genus                 Adenomera            Ameerega             Hypsiboas
# Species  AdenomeraHylaedactylus  Ameeregatrivittata  HypsiboasCinerascens
#
#                  Cluster 3
# Family             Hylidae
# Genus            Hypsiboas
# Species  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.222469
# Hamming_Score       0.777531
# Hamming_Distance    0.667408
# dtype: float64
#
#
# Iteration  32
# Best k:  4
#
#  Cluster Majority:
#                   Cluster 0               Cluster 1          Cluster 2  \
# Family        Dendrobatidae         Leptodactylidae            Hylidae
# Genus              Ameerega               Adenomera          Hypsiboas
# Species  Ameeregatrivittata  AdenomeraHylaedactylus  HypsiboasCordobae
#
#                     Cluster 3
# Family                Hylidae
# Genus               Hypsiboas
# Species  HypsiboasCinerascens
# Evaluations:
# Hamming_Loss        0.222423
# Hamming_Score       0.777577
# Hamming_Distance    0.667269
# dtype: float64
#
#
# Iteration  33
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1             Cluster 2  \
# Family          Leptodactylidae            Hylidae               Hylidae
# Genus                 Adenomera          Hypsiboas             Hypsiboas
# Species  AdenomeraHylaedactylus  HypsiboasCordobae  HypsiboasCinerascens
#
#                   Cluster 3
# Family        Dendrobatidae
# Genus              Ameerega
# Species  Ameeregatrivittata
# Evaluations:
# Hamming_Loss        0.222145
# Hamming_Score       0.777855
# Hamming_Distance    0.666435
# dtype: float64
#
#
# Iteration  34
# Best k:  4
#
#  Cluster Majority:
#                   Cluster 0               Cluster 1             Cluster 2  \
# Family        Dendrobatidae         Leptodactylidae               Hylidae
# Genus              Ameerega               Adenomera             Hypsiboas
# Species  Ameeregatrivittata  AdenomeraHylaedactylus  HypsiboasCinerascens
#
#                  Cluster 3
# Family             Hylidae
# Genus            Hypsiboas
# Species  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.222469
# Hamming_Score       0.777531
# Hamming_Distance    0.667408
# dtype: float64
#
#
# Iteration  35
# Best k:  4
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1             Cluster 2  \
# Family             Hylidae         Leptodactylidae               Hylidae
# Genus            Hypsiboas               Adenomera             Hypsiboas
# Species  HypsiboasCordobae  AdenomeraHylaedactylus  HypsiboasCinerascens
#
#                   Cluster 3
# Family        Dendrobatidae
# Genus              Ameerega
# Species  Ameeregatrivittata
# Evaluations:
# Hamming_Loss        0.222423
# Hamming_Score       0.777577
# Hamming_Distance    0.667269
# dtype: float64
#
#
# Iteration  36
# Best k:  4
#
#  Cluster Majority:
#                   Cluster 0               Cluster 1        Cluster 2  \
# Family        Dendrobatidae         Leptodactylidae  Leptodactylidae
# Genus              Ameerega               Adenomera        Adenomera
# Species  Ameeregatrivittata  AdenomeraHylaedactylus   AdenomeraAndre
#
#                  Cluster 3
# Family             Hylidae
# Genus            Hypsiboas
# Species  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.186055
# Hamming_Score       0.813945
# Hamming_Distance    0.558165
# dtype: float64
#
#
# Iteration  37
# Best k:  3
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1          Cluster 2
# Family          Leptodactylidae            Hylidae            Hylidae
# Genus                 Adenomera          Hypsiboas          Hypsiboas
# Species  AdenomeraHylaedactylus  HypsiboasCordobae  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.296780
# Hamming_Score       0.703220
# Hamming_Distance    0.890341
# dtype: float64
#
#
# Iteration  38
# Best k:  4
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1               Cluster 2  \
# Family             Hylidae         Leptodactylidae         Leptodactylidae
# Genus            Hypsiboas               Adenomera               Adenomera
# Species  HypsiboasCordobae  AdenomeraHylaedactylus  AdenomeraHylaedactylus
#
#                   Cluster 3
# Family        Dendrobatidae
# Genus              Ameerega
# Species  Ameeregatrivittata
# Evaluations:
# Hamming_Loss        0.239194
# Hamming_Score       0.760806
# Hamming_Distance    0.717582
# dtype: float64
#
#
# Iteration  39
# Best k:  5
#
#  Cluster Majority:
#                Cluster 0               Cluster 1             Cluster 2  \
# Family   Leptodactylidae         Leptodactylidae               Hylidae
# Genus          Adenomera               Adenomera             Hypsiboas
# Species   AdenomeraAndre  AdenomeraHylaedactylus  HypsiboasCinerascens
#
#                  Cluster 3           Cluster 4
# Family             Hylidae       Dendrobatidae
# Genus            Hypsiboas            Ameerega
# Species  HypsiboasCordobae  Ameeregatrivittata
# Evaluations:
# Hamming_Loss        0.167894
# Hamming_Score       0.832106
# Hamming_Distance    0.503683
# dtype: float64
#
#
# Iteration  40
# Best k:  6
#
#  Cluster Majority:
#                Cluster 0               Cluster 1          Cluster 2  \
# Family   Leptodactylidae         Leptodactylidae            Hylidae
# Genus          Adenomera               Adenomera          Hypsiboas
# Species   AdenomeraAndre  AdenomeraHylaedactylus  HypsiboasCordobae
#
#                   Cluster 3             Cluster 4           Cluster 5
# Family        Dendrobatidae               Hylidae       Dendrobatidae
# Genus              Ameerega             Hypsiboas            Ameerega
# Species  Ameeregatrivittata  HypsiboasCinerascens  Ameeregatrivittata
# Evaluations:
# Hamming_Loss        0.167616
# Hamming_Score       0.832384
# Hamming_Distance    0.502849
# dtype: float64
#
#
# Iteration  41
# Best k:  4
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1        Cluster 2  \
# Family             Hylidae         Leptodactylidae  Leptodactylidae
# Genus            Hypsiboas               Adenomera        Adenomera
# Species  HypsiboasCordobae  AdenomeraHylaedactylus   AdenomeraAndre
#
#                  Cluster 3
# Family             Hylidae
# Genus            Hypsiboas
# Species  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.247533
# Hamming_Score       0.752467
# Hamming_Distance    0.742599
# dtype: float64
#
#
# Iteration  42
# Best k:  4
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1          Cluster 2  \
# Family             Hylidae         Leptodactylidae            Hylidae
# Genus            Hypsiboas               Adenomera          Hypsiboas
# Species  HypsiboasCordobae  AdenomeraHylaedactylus  HypsiboasCordobae
#
#                       Cluster 3
# Family          Leptodactylidae
# Genus                 Adenomera
# Species  AdenomeraHylaedactylus
# Evaluations:
# Hamming_Loss        0.298216
# Hamming_Score       0.701784
# Hamming_Distance    0.894649
# dtype: float64
#
#
# Iteration  43
# Best k:  6
#
#  Cluster Majority:
#                   Cluster 0          Cluster 1               Cluster 2  \
# Family        Dendrobatidae            Hylidae         Leptodactylidae
# Genus              Ameerega          Hypsiboas               Adenomera
# Species  Ameeregatrivittata  HypsiboasCordobae  AdenomeraHylaedactylus
#
#                     Cluster 3               Cluster 4        Cluster 5
# Family                Hylidae         Leptodactylidae  Leptodactylidae
# Genus               Hypsiboas               Adenomera        Adenomera
# Species  HypsiboasCinerascens  AdenomeraHylaedactylus   AdenomeraAndre
# Evaluations:
# Hamming_Loss        0.199398
# Hamming_Score       0.800602
# Hamming_Distance    0.598193
# dtype: float64
#
#
# Iteration  44
# Best k:  3
#
#  Cluster Majority:
#                  Cluster 0               Cluster 1          Cluster 2
# Family             Hylidae         Leptodactylidae            Hylidae
# Genus            Hypsiboas               Adenomera          Hypsiboas
# Species  HypsiboasCordobae  AdenomeraHylaedactylus  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.296780
# Hamming_Score       0.703220
# Hamming_Distance    0.890341
# dtype: float64
#
#
# Iteration  45
# Best k:  2
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1
# Family          Leptodactylidae            Hylidae
# Genus                 Adenomera          Hypsiboas
# Species  AdenomeraHylaedactylus  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.298541
# Hamming_Score       0.701459
# Hamming_Distance    0.895622
# dtype: float64
#
#
# Iteration  46
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0           Cluster 1          Cluster 2  \
# Family          Leptodactylidae       Dendrobatidae            Hylidae
# Genus                 Adenomera            Ameerega          Hypsiboas
# Species  AdenomeraHylaedactylus  Ameeregatrivittata  HypsiboasCordobae
#
#                     Cluster 3
# Family                Hylidae
# Genus               Hypsiboas
# Species  HypsiboasCinerascens
# Evaluations:
# Hamming_Loss        0.222423
# Hamming_Score       0.777577
# Hamming_Distance    0.667269
# dtype: float64
#
#
# Iteration  47
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1          Cluster 2  \
# Family          Leptodactylidae            Hylidae            Hylidae
# Genus                 Adenomera          Hypsiboas          Hypsiboas
# Species  AdenomeraHylaedactylus  HypsiboasCordobae  HypsiboasCordobae
#
#                       Cluster 3
# Family          Leptodactylidae
# Genus                 Adenomera
# Species  AdenomeraHylaedactylus
# Evaluations:
# Hamming_Loss        0.298077
# Hamming_Score       0.701923
# Hamming_Distance    0.894232
# dtype: float64
#
#
# Iteration  48
# Best k:  4
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1               Cluster 2  \
# Family          Leptodactylidae            Hylidae         Leptodactylidae
# Genus                 Adenomera          Hypsiboas               Adenomera
# Species  AdenomeraHylaedactylus  HypsiboasCordobae  AdenomeraHylaedactylus
#
#                  Cluster 3
# Family             Hylidae
# Genus            Hypsiboas
# Species  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.297938
# Hamming_Score       0.702062
# Hamming_Distance    0.893815
# dtype: float64
#
#
# Iteration  49
# Best k:  8
#
#  Cluster Majority:
#                       Cluster 0          Cluster 1        Cluster 2  \
# Family          Leptodactylidae            Hylidae  Leptodactylidae
# Genus                 Adenomera          Hypsiboas        Adenomera
# Species  AdenomeraHylaedactylus  HypsiboasCordobae   AdenomeraAndre
#
#                Cluster 3            Cluster 4               Cluster 5  \
# Family   Leptodactylidae      Leptodactylidae         Leptodactylidae
# Genus          Adenomera        Leptodactylus               Adenomera
# Species   AdenomeraAndre  LeptodactylusFuscus  AdenomeraHylaedactylus
#
#                       Cluster 6             Cluster 7
# Family          Leptodactylidae               Hylidae
# Genus                 Adenomera             Hypsiboas
# Species  AdenomeraHylaedactylus  HypsiboasCinerascens
# Evaluations:
# Hamming_Loss        0.189252
# Hamming_Score       0.810748
# Hamming_Distance    0.567755
# dtype: float64
#
#
# Iteration  50
# Best k:  4
#
#  Cluster Majority:
#                   Cluster 0               Cluster 1             Cluster 2  \
# Family        Dendrobatidae         Leptodactylidae               Hylidae
# Genus              Ameerega               Adenomera             Hypsiboas
# Species  Ameeregatrivittata  AdenomeraHylaedactylus  HypsiboasCinerascens
#
#                  Cluster 3
# Family             Hylidae
# Genus            Hypsiboas
# Species  HypsiboasCordobae
# Evaluations:
# Hamming_Loss        0.245634
# Hamming_Score       0.754366
# Hamming_Distance    0.736901
# dtype: float64

# %% [markdown]
# ### (c) Now for each cluster you have a majority label triplet (family, genus, species). Calculate the average Hamming distance, Hamming score, and Hamming loss between the true labels and the labels assigned by clusters.

# %%
dfscores = pd.DataFrame(scores)
print('Average of:\n',dfscores.mean())
# Out:
# Average of:
#  Hamming_Loss        0.232048
# Hamming_Score       0.767952
# Hamming_Distance    0.696145
# dtype: float64

# %% [markdown]
# ### Reference:
#
# #### https://towardsdatascience.com/kmeans-clustering-for-classification-74b992405d0a
# #### https://towardsdatascience.com/silhouette-coefficient-validating-clustering-techniques-e976bb81d10c#:~:text=Silhouette%20Coefficient%20or%20silhouette%20score%20is%20a%20metric%20used%20to,each%20other%20and%20clearly%20distinguished.&text=a%3D%20average%20intra%2Dcluster%20distance,each%20point%20within%20a%20cluster
